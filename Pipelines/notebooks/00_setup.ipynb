# %%
import sys
# -----------------------------
# Ajouter le repo au Python Path
# -----------------------------
sys.path.append("/Workspace/Users/mandu543@gmail.com/databricks-ecommerce/Pipelines/")

from lib.utils import *

# %%
create_schema_if_not_exists(spark,BRONZE_ZONE)
create_schema_if_not_exists(spark,SILVER_ZONE)
create_schema_if_not_exists(spark,GOLD_ZONE)
