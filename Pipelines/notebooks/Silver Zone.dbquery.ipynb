-- %%
select * from workspace.02_silver.slv_ecommerce_customers limit 5;
select * from workspace.02_silver.slv_ecommerce_brands limit 5;
select * from slv_ecommerce_order_items;

/*
drop table if exists workspace.02_silver.slv_ecommerce_order_items;
drop table if exists slv_ecommerce_brands;
drop table if exists slv_ecommerce_products;
drop table if exists slv_ecommerce_categories;
drop table if exists workspace.02_silver.slv_ecommerce_customers;
*/
